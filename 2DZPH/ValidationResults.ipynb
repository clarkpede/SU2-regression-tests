# %% [markdown]
# # Supersonic Flat Plate
#
# + Supersonic
# + 2D
# + Zero pressure gradient
#
# See https://turbmodels.larc.nasa.gov/ZPGflatplateSS_val.html

# %%
import matplotlib.pyplot as plt
import sys
sys.path.append('/workspace/code/SU2-test/regression/')
from regression_plots import surfaceplot, histplot
plt.style.use(('seaborn-whitegrid', 'seaborn-notebook'))

# %% [markdown]
# ## SST

# %%
commits = ["e81ebed", "2ce55b5"]
formats = ["-", "--", ":"]

# %%
fig, ax = surfaceplot("SST", commits, formats)
ax[0].set_xlim([0.10, 1.8])
ax[0].set_ylim([0.0025, 0.0045])
ax[1].set_ylim([0.0015, 0.0026])
fig.savefig("2DZPH_sst_surface.png")

# %%
fig, ax = histplot("SST", commits, formats)
fig.savefig("2DZPH_sst_history.png")

# %% [markdown]
# ## v2-f

# %%
commits = ["e81ebed", "3b33ff3", "be4fb8b"]
formats = ["-", "--", ":"]

# %%
fig, ax = surfaceplot("v2f", commits, formats)
ax[0].set_xlim([0.10, 1.8])
ax[0].set_ylim([0.0025, 0.0045])
ax[1].set_ylim([0.0015, 0.0026])
fig.savefig("2DZPH_v2f_surface.png")

# %%
fig, ax = histplot("v2f", commits, formats)
fig.savefig("2DZPH_v2f_history.png")
